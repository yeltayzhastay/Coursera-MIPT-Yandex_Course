# %% [markdown]
# # Зарплаты в России

# %%
# %pylab inline
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import warnings
from itertools import product

def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Считывание данных
WAG = pd.read_csv('WAG_C_M.csv',';', index_col=['month'], parse_dates=['month'], dayfirst=True)
WAG.head()
# Out:
#             WAG_C_M
# month
# 1993-01-01     15.3
# 1993-02-01     19.1
# 1993-03-01     23.6
# 1993-04-01     30.6
# 1993-05-01     37.5

# %% [markdown]
# ### Визуальный анализ ряда

# %%
plt.figure(figsize(15,7))
WAG.WAG_C_M.plot()
plt.ylabel('Средн_зарплаты')
pylab.show()

# %% [markdown]
#  Из визуального анализа следует: ряд имеет возрастающий трент, имеется сезонность, дисперсия возрастает, стационарность отсутствует

# %% [markdown]
# ### Проверка стационарности и STL-декомпозиция ряда:

# %%
plt.figure(figsize(15,10))
sm.tsa.seasonal_decompose(WAG.WAG_C_M).plot()
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(WAG.WAG_C_M)[1])
# Out:
# Критерий Дики-Фуллера: p=0.991850

# %% [markdown]
# Критерий Дики-Фулерра подтверждает отсутствие стационарности, STL-декомпозиция ряда демонстрирует наличие тренда и сезонность

# %% [markdown]
# ### Стабилизация дисперсии

# %% [markdown]
# Сделаем преобразование Бокса-Кокса для стабилизации дисперсии:

# %%
WAG['WAG_C_M_BC'], lmbda = stats.boxcox(WAG.WAG_C_M)
plt.figure(figsize(15,7))
WAG.WAG_C_M_BC.plot()
plt.ylabel(u'Transformed data')
print("Оптимальный параметр преобразования Бокса-Кокса: %f" % lmbda)
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(WAG.WAG_C_M_BC)[1])
# Out:
# Оптимальный параметр преобразования Бокса-Кокса: 0.263202
# Критерий Дики-Фуллера: p=0.696899

# %% [markdown]
# ### Стационарность

# %% [markdown]
# Критерий Дики-Фулерра по прежнему подтверждает отсутствие стационарности, наблюдаем тренд. Попробуем сезонное дифференцирование; сделаем на продифференцированном ряде STL-декомпозицию и проверим стационарность:

# %%
WAG['WAG_C_M_BC_diff'] = WAG.WAG_C_M_BC - WAG.WAG_C_M_BC.shift(12)
plt.figure(figsize(15,10))
sm.tsa.seasonal_decompose(WAG.WAG_C_M_BC_diff[12:]).plot()
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(WAG.WAG_C_M_BC_diff[12:])[1])
# Out:
# Критерий Дики-Фуллера: p=0.014697

# %% [markdown]
# Критерий Дики-Фуллера уже отвергает гипотезу нестационарности, и полностью избавиться от тренда не удалось. Попробуем добавить ещё обычное дифференцирование:

# %%
WAG['WAG_C_M_BC_diff2'] = WAG.WAG_C_M_BC_diff - WAG.WAG_C_M_BC_diff.shift(1)
plt.figure(figsize(15,10))
sm.tsa.seasonal_decompose(WAG.WAG_C_M_BC_diff2[13:]).plot()   
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(WAG.WAG_C_M_BC_diff2[13:])[1])
# Out:
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Гипотеза нестационарности отвергается, и визуально ряд выглядит лучше — тренда больше нет.

# %% [markdown]
# ## Подбор модели

# %% [markdown]
# Посмотрим на ACF и PACF полученного ряда:

# %%
plt.figure(figsize(15,8))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(WAG.WAG_C_M_BC_diff2[13:].values.squeeze(), lags=48, ax=ax)
pylab.show()
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(WAG.WAG_C_M_BC_diff2[13:].values.squeeze(), lags=48, ax=ax)
pylab.show()

# %% [markdown]
# Начальные приближения: Q=0, q=5, P=4, p=11

# %%
ps = range(0, 12)
d=1
qs = range(0, 6)
Ps = range(0, 5)
D=1
Qs = range(0, 1)

# %%
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 360

# %%
# %%time
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.statespace.SARIMAX(WAG.WAG_C_M_BC, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
warnings.filterwarnings('default')
# Out:
# Wall time: 2h 21min 47s

# %%
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
# Out:
#        parameters        aic
# 176  (5, 5, 1, 0) -25.177430
# 201  (6, 4, 1, 0) -24.843548
# 146  (4, 5, 1, 0) -23.879883
# 177  (5, 5, 2, 0) -23.368409
# 206  (6, 5, 1, 0) -22.750098

# %% [markdown]
# Лучшая модель:

# %%
print(best_model.summary())
# Out:
#                                       SARIMAX Results
# ...
# Dep. Variable:                          WAG_C_M_BC   No. Observations:                  284
# Model:             SARIMAX(5, 1, 5)x(1, 1, [], 12)   Log Likelihood                  24.589
# Date:                             Sat, 05 Sep 2020   AIC                            -25.177
# Time:                                     16:32:52   BIC                             18.048
# Sample:                                 01-01-1993   HQIC                            -7.822
#                                       - 08-01-2016
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2247      0.450     -0.500      0.617      -1.106       0.657
# ar.L2          0.2373      0.313      0.757      0.449      -0.377       0.851
# ...

# %% [markdown]
# ## Её остатки:

# %%
plt.figure(figsize(15,8))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')

ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Критерий Стьюдента: p=%f" % stats.ttest_1samp(best_model.resid[13:], 0)[1])
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])
# Out:
# Критерий Стьюдента: p=0.159384
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Остатки несмещены (подтверждается критерием Стьюдента) стационарны (подтверждается критерием Дики-Фуллера и визуально), неавтокоррелированы (подтверждается  коррелограммой).
# Посмотрим, насколько хорошо модель описывает данные:

# %%
WAG['model'] = invboxcox(best_model.fittedvalues, lmbda)
plt.figure(figsize(15,7))
WAG.WAG_C_M.plot()
WAG.model[13:].plot(color='r')
plt.ylabel('WAG model')
pylab.show()

# %% [markdown]
# ### Прогноз

# %%
WAG2 = WAG[['WAG_C_M']]
date_list = [datetime.datetime.strptime("2016-09-01", "%Y-%m-%d") + relativedelta(months=x) for x in range(0,24)]
future = pd.DataFrame(index=date_list, columns= WAG2.columns)
WAG2 = pd.concat([WAG2, future])
WAG2['forecast'] = invboxcox(best_model.predict(start=284, end=307), lmbda)
plt.figure(figsize(15,7))
WAG2.WAG_C_M.plot()
WAG2.forecast.plot(color='r')
plt.ylabel('WAG')
pylab.show()
